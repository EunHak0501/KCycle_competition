# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm 
import pandas as pd
import requests
import re
import time
import KCycle_crawller as KC

# %%
driver = webdriver.Chrome()

# %% [markdown]
# # 해당 연도에서 추출할 경기들 리스트

# %%
year_list = ['2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']
연도 = year_list[0]

url = f'https://www.kcycle.or.kr/contents/information/fixedChuljuPage.do?stndYear={연도}&tms_dayOrd=01-1'
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')

# %%
base_raw = soup.find('select', attrs={'name': 'tms_dayOrd'})
data_list = [td.get_text(strip=True) for td in base_raw.find_all('option')]

race_day_list = []
for item in data_list:
    match = re.search(r'\((\d+)회 (\d+)일\)', item)
    if match:
        day = int(match.group(2))
        if 1 <= day <= 3:
            race_day_list.append((match.group(1), match.group(2)))

race_day_list.reverse()
race_day_list
# Out:
# [('01', '1'),
#  ('01', '2'),
#  ('01', '3'),
#  ('02', '1'),
#  ('02', '2'),
#  ('02', '3'),
#  ('03', '1'),
#  ('03', '2'),
#  ('03', '3'),
#  ('04', '1'),
#  ('04', '2'),
#  ('04', '3'),
#  ('05', '1'),
#  ('05', '2'),
#  ('05', '3'),
#  ('06', '1'),
#  ('06', '2'),
#  ('06', '3'),
#  ('07', '1'),
#  ('07', '2'),
#  ('07', '3'),
#  ('08', '1'),
#  ('08', '2'),
#  ('08', '3'),
#  ('09', '1'),
#  ('09', '2'),
#  ('09', '3'),
#  ('10', '1'),
#  ('10', '2'),
#  ('10', '3'),
#  ('11', '1'),
#  ('11', '2'),
#  ('11', '3'),
#  ('12', '1'),
#  ('12', '2'),
#  ('12', '3'),
#  ('13', '1'),
#  ('13', '2'),
#  ('13', '3'),
#  ('14', '1'),
#  ('14', '2'),
#  ('14', '3'),
#  ('15', '1'),
#  ('15', '2'),
#  ('15', '3'),
#  ('16', '1'),
#  ('16', '2'),
#  ('16', '3'),
#  ('17', '1'),
#  ('17', '2'),
#  ('17', '3'),
#  ('18', '1'),
#  ('18', '2'),
#  ('18', '3'),
#  ('19', '1'),
#  ('19', '2'),
#  ('19', '3'),
#  ('20', '1'),
#  ('20', '2'),
#  ('20', '3'),
#  ('21', '1'),
#  ('21', '2'),
#  ('21', '3'),
#  ('22', '1'),
#  ('22', '2'),
#  ('22', '3'),
#  ('23', '1'),
#  ('23', '2'),
#  ('23', '3'),
#  ('24', '1'),
#  ('24', '2'),
#  ('24', '3'),
#  ('25', '1'),
#  ('25', '2'),
#  ('25', '3'),
#  ('26', '1'),
#  ('26', '2'),
#  ('26', '3'),
#  ('27', '1'),
#  ('27', '2'),
#  ('27', '3'),
#  ('28', '1'),
#  ('28', '2'),
#  ('28', '3'),
#  ('29', '1'),
#  ('29', '2'),
#  ('29', '3'),
#  ('30', '1'),
#  ('30', '2'),
#  ('30', '3'),
#  ('31', '1'),
#  ('31', '2'),
#  ('31', '3'),
#  ('32', '1'),
#  ('32', '2'),
#  ('32', '3'),
#  ('33', '1'),
#  ('33', '2'),
#  ('33', '3'),
#  ('34', '1'),
#  ('34', '2'),
#  ('34', '3'),
#  ('35', '1'),
#  ('35', '2'),
#  ('35', '3'),
#  ('36', '1'),
#  ('36', '2'),
#  ('36', '3'),
#  ('37', '1'),
#  ('37', '2'),
#  ('37', '3'),
#  ('38', '1'),
#  ('38', '2'),
#  ('38', '3'),
#  ('39', '1'),
#  ('39', '2'),
#  ('39', '3'),
#  ('40', '1'),
#  ('40', '2'),
#  ('40', '3'),
#  ('41', '1'),
#  ('41', '2'),
#  ('41', '3'),
#  ('42', '1'),
#  ('42', '2'),
#  ('42', '3'),
#  ('43', '1'),
#  ('43', '2'),
#  ('43', '3'),
#  ('44', '1'),
#  ('44', '2'),
#  ('44', '3'),
#  ('45', '1'),
#  ('45', '2'),
#  ('45', '3'),
#  ('46', '1'),
#  ('46', '2'),
#  ('47', '1'),
#  ('47', '2'),
#  ('47', '3'),
#  ('48', '1'),
#  ('48', '2'),
#  ('48', '3'),
#  ('49', '1'),
#  ('49', '2'),
#  ('49', '3'),
#  ('50', '1'),
#  ('50', '2'),
#  ('50', '3')]

# %% [markdown]
# ### URL 접속

# %%
회차, 일차 = race_day_list[0]
print(f'회차: {회차}, 일차: {일차}')

url = f'https://www.kcycle.or.kr/contents/information/fixedChuljuPage.do?stndYear={연도}&tms_dayOrd={회차}-{일차}'
driver.get(url)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
# Out:
# 회차: 01, 일차: 1

# %%
strong_text = soup.find('strong').text

# 날짜 패턴 검색 (연도 포함)
date_match = re.search(r'(\d{4})년 (\d{2})월 (\d{2})일', strong_text)
if date_match:
    # 'YYMMDD' 형식으로 포맷 (연도의 마지막 두 자리만 사용)
    year_last_two = date_match.group(1)[-2:]  # 연도의 마지막 두 자리
    month = date_match.group(2)  # 월
    day = date_match.group(3)    # 일
    Date = year_last_two + month + day
else:
    Date = None

print(Date)
# Out:
# 170106

# %%
base_raw = soup.find('div', class_='turn badge-group mt15')
race_string = [td.get_text(strip=True) for td in base_raw.find_all('span')]
race_string

numbers = [re.search(r'\d+', item).group() for item in race_string if '광' in item]
numbers
# Out:
# ['01',
#  '02',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '08',
#  '09',
#  '10',
#  '11',
#  '12',
#  '13',
#  '14']

# %% [markdown]
# ### 해당 경기가 포함된 태그 찾기 (ex 광명01 포함된 태그 찾기)
#
# 출주표 페이지의 html코드가 각 경기마다 같은 구조로 나열되어있기 때문에 해당하는 경기를 찾는게 편함

# %%
target_경기 = numbers[13]
div_found = KC.find_race(soup, race_num=target_경기)

# %% [markdown]
# ### 해당 경기의 출주표 데이터 추출
# - 기본 출주표

# %%
method = 3
threshold = 3

year_list = ['2017', '2018', '2019', '2020', '2022', '2023', '2024'] # 2021년 데이터는 오류 발생
# year_list = ['2021']

final_data_merged = pd.DataFrame()

for z in range(len(year_list)):
    연도 = year_list[z]
    
    url = f'https://www.kcycle.or.kr/contents/information/fixedChuljuPage.do?stndYear={연도}&tms_dayOrd=01-1'
    driver.get(url)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    
    base_raw = soup.find('select', attrs={'name': 'tms_dayOrd'})
    data_list = [td.get_text(strip=True) for td in base_raw.find_all('option')]
    
    race_day_list = []
    for item in data_list:
        match = re.search(r'\((\d+)회 (\d+)일\)', item)
        if match:
            day = int(match.group(2))
            if 1 <= day <= 3:
                race_day_list.append((match.group(1), match.group(2)))
    
    race_day_list.reverse()
    
    year_data_merged = pd.DataFrame()
    
    pbar = tqdm(range(len(race_day_list)), desc='Initializing')
    for j in range(len(race_day_list)):
        회차, 일차 = race_day_list[j]
        pbar.set_description(f'Processing Year: {연도}, 회차: {회차}, 일차: {일차}')
        pbar.update(1)
        
        # print(f'연도: {연도}, 회차: {회차}, 일차: {일차}')
        
        url = f'https://www.kcycle.or.kr/contents/information/fixedChuljuPage.do?stndYear={연도}&tms_dayOrd={회차}-{일차}'
        driver.get(url)
        
        html = driver.page_source
        soup_race = BeautifulSoup(html, 'html.parser')
    
        strong_text = soup_race.find('strong').text
        
        date_match = re.search(r'(\d{4})년 (\d{2})월 (\d{2})일', strong_text)
        if date_match:
            # 'YYMMDD' 형식
            year_last_two = date_match.group(1)[-2:]
            month = date_match.group(2)  
            day = date_match.group(3)  
            Date = year_last_two + month + day
        else:
            Date = None
    
        base_raw = soup_race.find('div', class_='turn badge-group mt15')
        race_string = [td.get_text(strip=True) for td in base_raw.find_all('span')]
        
        numbers = [re.search(r'\d+', item).group() for item in race_string if '광' in item]
    
        
        day_data_merged = pd.DataFrame()
        processed_races = []
        
        for i in range(len(numbers)):
            try:
                # time.sleep(0.01)
                target_경기 = numbers[i]
                div_found = KC.find_race(soup_race, race_num=target_경기)
                
                date_info = pd.DataFrame({
                    "BASE_YEAR": [연도] * 7,
                    "TME_VALUE": [회차] * 7,
                    "DAY_ORD_VALUE": [일차] * 7,
                    "RACE_NO": [target_경기] * 7,
                    "Date": [Date] * 7
                })
                
                data_base = KC.baseinfo(div_found, method=method, threshold=3)
                if len(data_base) != 7:
                    print(f"Skipping {회차}회차 and {일차}일차 and 광명{target_경기}경주: {len(data_base)}명이 진행한 경기는 제외합니다.")
                    continue
                
                data_training = KC.training_info(div_found)
                
                data_recent_tmp = KC.recent_result(div_found)
                data_recent = KC.recent_result_process(data_recent_tmp)
            
                data_merged = pd.concat([
                    date_info,
                    data_base,
                    data_training[['훈련일수', '훈련내용']],
                    data_recent.iloc[:, 2:],
                ], axis=1)
            
                day_data_merged = pd.concat([day_data_merged, data_merged], ignore_index=True)
                day_data_merged.reset_index(drop=True, inplace=True)
                processed_races.append(target_경기)  # 성공적으로 처리된 경기 저장
            except Exception as e:
                print(f"Error processing race in {회차}회차 and {일차}일차 and 광명{target_경기}경주: {e}")
                continue
        
        url = f'https://www.kcycle.or.kr/contents/information/raceResultPage.do?stndYear={연도}&tms_dayOrd={회차}-{일차}'
        response = requests.get(url)
        html_content = response.text
        soup_result = BeautifulSoup(html_content, 'html.parser')
        # print(processed_races)
        result_df = KC.fetch_race_results(soup_race, soup_result, 연도, 회차, 일차)
        filtered_results = result_df[result_df['RACE_NO'].isin(processed_races)]
        filtered_results.reset_index(drop=True, inplace=True)
        
        day_data_merged = pd.concat([day_data_merged, filtered_results['rank']], axis=1)
        
        year_data_merged = pd.concat([year_data_merged, day_data_merged], ignore_index=True)
    
    pbar.close()
    final_data_merged = pd.concat([final_data_merged, year_data_merged], ignore_index=True)
# Out:
# Initializing:   0%|          | 0/149 [00:00<?, ?it/s]
# Error processing race in 08회차 and 1일차 and 광명04경주: Columns must be same length as key
# Error processing race in 13회차 and 1일차 and 광명07경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Skipping 17회차 and 1일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 17회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 18회차 and 1일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 18회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 19회차 and 1일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 19회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 20회차 and 1일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 20회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 21회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 22회차 and 2일차 and 광명15경주: 8명이 진행한 경기는 제외합니다.
# Skipping 26회차 and 3일차 and 광명16경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 1일차 and 광명10경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 2일차 and 광명10경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 3일차 and 광명10경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 34회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 39회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 39회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 40회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 40회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 41회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 41회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 42회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 42회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 43회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 43회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 44회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 44회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 45회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 45회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 45회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Initializing:   0%|          | 0/151 [00:00<?, ?it/s]
# Skipping 09회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 09회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Error processing race in 10회차 and 1일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Skipping 10회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 10회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 11회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 11회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 12회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 12회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 12회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 13회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 13회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 13회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 14회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 14회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 14회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Error processing race in 17회차 and 3일차 and 광명15경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Skipping 38회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 38회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 38회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 39회차 and 1일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 39회차 and 2일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 39회차 and 3일차 and 광명12경주: 8명이 진행한 경기는 제외합니다.
# Skipping 40회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 40회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 40회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 41회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 41회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 41회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Error processing race in 42회차 and 3일차 and 광명05경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Initializing:   0%|          | 0/153 [00:00<?, ?it/s]
# Skipping 14회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 14회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 14회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 15회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 1일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 2일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Skipping 16회차 and 3일차 and 광명11경주: 8명이 진행한 경기는 제외합니다.
# Error processing race in 22회차 and 1일차 and 광명14경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 24회차 and 1일차 and 광명10경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 44회차 and 3일차 and 광명10경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Initializing:   0%|          | 0/34 [00:00<?, ?it/s]
# Error processing race in 02회차 and 1일차 and 광명10경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 04회차 and 1일차 and 광명07경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 43회차 and 1일차 and 광명04경주: Columns must be same length as key
# Initializing:   0%|          | 0/154 [00:00<?, ?it/s]
# Error processing race in 02회차 and 3일차 and 광명13경주: Columns must be same length as key
# Error processing race in 08회차 and 1일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 08회차 and 1일차 and 광명11경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 08회차 and 1일차 and 광명12경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 08회차 and 2일차 and 광명14경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 10회차 and 1일차 and 광명08경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 12회차 and 1일차 and 광명11경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 23회차 and 1일차 and 광명13경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 25회차 and 3일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 27회차 and 3일차 and 광명08경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 40회차 and 3일차 and 광명02경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 48회차 and 1일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 49회차 and 1일차 and 광명08경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 50회차 and 1일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 50회차 and 2일차 and 광명11경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 50회차 and 3일차 and 광명08경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 51회차 and 2일차 and 광명10경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Initializing:   0%|          | 0/152 [00:00<?, ?it/s]
# Error processing race in 05회차 and 1일차 and 광명09경주: Columns must be same length as key
# Error processing race in 07회차 and 1일차 and 광명15경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 09회차 and 2일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 14회차 and 3일차 and 광명11경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 15회차 and 1일차 and 광명02경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 15회차 and 1일차 and 광명07경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 16회차 and 1일차 and 광명08경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 17회차 and 2일차 and 광명01경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 20회차 and 2일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 27회차 and 1일차 and 광명08경주: Columns must be same length as key
# Error processing race in 33회차 and 2일차 and 광명05경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 34회차 and 1일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 36회차 and 2일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 39회차 and 3일차 and 광명13경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 41회차 and 2일차 and 광명11경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 47회차 and 1일차 and 광명05경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 47회차 and 2일차 and 광명04경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 47회차 and 2일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 49회차 and 2일차 and 광명09경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 50회차 and 3일차 and 광명07경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Error processing race in 51회차 and 3일차 and 광명06경주: int() argument must be a string, a bytes-like object or a number, not 'NoneType'
# Initializing:   0%|          | 0/53 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 112
#     110 # print(processed_races)
#     111 result_df = KC.fetch_race_results(soup_race, soup_result, 연도, 회차, 일차)
# --> 112 filtered_results = result_df[result_df['RACE_NO'].isin(processed_races)]
#     113 filtered_results.reset_index(drop=True, inplace=True)
#     115 day_data_merged = pd.concat([day_data_merged, filtered_results['rank']], axis=1)
#
# File ~\anaconda3\envs\eunhak3.8\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\envs\eunhak3.8\lib\site-packages\pandas\core\indexes\range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'RACE_NO'

# %%
race_day_list
# Out:
# [('01', '1'),
#  ('01', '2'),
#  ('01', '3'),
#  ('02', '1'),
#  ('02', '2'),
#  ('02', '3'),
#  ('03', '1'),
#  ('03', '2'),
#  ('03', '3'),
#  ('04', '1'),
#  ('04', '2'),
#  ('04', '3'),
#  ('05', '1'),
#  ('05', '2'),
#  ('05', '3'),
#  ('06', '1'),
#  ('06', '2'),
#  ('06', '3'),
#  ('07', '1'),
#  ('07', '2'),
#  ('07', '3'),
#  ('08', '1'),
#  ('08', '2'),
#  ('08', '3'),
#  ('09', '1'),
#  ('09', '2'),
#  ('09', '3'),
#  ('10', '1'),
#  ('10', '2'),
#  ('10', '3'),
#  ('11', '1'),
#  ('11', '2'),
#  ('11', '3'),
#  ('12', '1'),
#  ('12', '2'),
#  ('12', '3'),
#  ('13', '1'),
#  ('13', '2'),
#  ('13', '3'),
#  ('14', '1'),
#  ('14', '2'),
#  ('14', '3'),
#  ('15', '1'),
#  ('15', '2'),
#  ('15', '3'),
#  ('16', '1'),
#  ('16', '2'),
#  ('16', '3'),
#  ('17', '1'),
#  ('17', '2'),
#  ('17', '3'),
#  ('18', '1'),
#  ('18', '2')]

# %%
condition = final_data_merged['RACE_NO'].isna()

final_data_merged[condition]
# Out:
#       BASE_YEAR TME_VALUE DAY_ORD_VALUE RACE_NO    Date 번호  선수명  색상  기수  나이  \
# 10990      2017        38             1      01  171006  1  김용진   백   8  40
# 10991      2017        38             1      01  171006  2  장동민   흑  12  36
# 10992      2017        38             1      01  171006  3  김태원   적  12  38
# 10993      2017        38             1      01  171006  4  용석길   청   3  46
# 10994      2017        38             1      01  171006  5  권용재   황   9  45
# ...         ...       ...           ...     ...     ... ..  ...  ..  ..  ..
# 82504      2023        50             3      15  231224  3  윤현구   적  22  32
# 82505      2023        50             3      15  231224  4  류재민   청  15  38
# 82506      2023        50             3      15  231224  5  박용범   황  18  35
# 82507      2023        50             3      15  231224  6  박성현   녹  16  38
# 82508      2023        50             3      15  231224  7  엄정일  분홍  19  36
#
#        ... 1회전2일차등수 1회전2일차전법 1회전3일차등수 1회전3일차전법 금회1일차등수 금회1일차전법 금회2일차등수  \
# 10990  ...        5     None        3      마마크    None    None    None
# 10991  ...        3      마마크        1      추추입    None    None    None
# 10992  ...        2      마마크        6     None    None    None    None
# 10993  ...        7     None        4     None    None    None    None
# 10994  ...        4     None        6     None    None    None    None
# ...    ...      ...      ...      ...      ...     ...     ...     ...
# 82504  ...        5     None        7     None       5    None       7
# 82505  ...        4     None        7     None       6    None       6
# 82506  ...        1      추추입        3      추추입       1     추추입       1
# 82507  ...        3      마마크        3      마마크       7    None       4
# 82508  ...        4     None        3      마마크       4    None       2
#
#       금회2일차전법  rank 금회3일차
# 10990    None  None
# 10991    None     2
# 10992    None  None
# 10993    None  None
# 10994    None  None
# ...       ...   ...   ...
# 82504    None  None
# 82505    None  None
# 82506     추추입     1
# 82507    None  None
# 82508     마마크     3
#
# [3808 rows x 59 columns]

# %%
final_data_merged
# Out:
#       BASE_YEAR TME_VALUE DAY_ORD_VALUE RACE_NO    Date 번호  선수명  색상  기수  나이  \
# 0          2017        01             1      01  170106  1  정영훈   백   6  44
# 1          2017        01             1      01  170106  2  설영석   흑  19  30
# 2          2017        01             1      01  170106  3  한지혁   적   6  38
# 3          2017        01             1      01  170106  4  김지은   청   6  44
# 4          2017        01             1      01  170106  5  감병삼   황   9  41
# ...         ...       ...           ...     ...     ... ..  ...  ..  ..  ..
# 82812      2023        51             3      15  231231  3  류재열   적  19  36
# 82813      2023        51             3      15  231231  4  성낙송   청  21  33
# 82814      2023        51             3      15  231231  5  황인혁   황  21  35
# 82815      2023        51             3      15  231231  6  임채빈   녹  25  32
# 82816      2023        51             3      15  231231  7  신은섭  분홍  18  36
#
#        ... 1회전2일차등수 1회전2일차전법 1회전3일차등수 1회전3일차전법 금회1일차등수 금회1일차전법 금회2일차등수  \
# 0      ...        4     None        3      마마크    None    None    None
# 1      ...        6     None        7     None    None    None    None
# 2      ...        3      마마크        5     None    None    None    None
# 3      ...        2      마마크        2      마마크    None    None    None
# 4      ...        7     None        3      추추입    None    None    None
# ...    ...      ...      ...      ...      ...     ...     ...     ...
# 82812  ...        1      추추입        2      선선발       1     추추입       2
# 82813  ...        2      마마크        3      마마크       1    젖젖히기       1
# 82814  ...        2      추추입        7     None       2     추추입       1
# 82815  ...        1      선선발        1      선선발       1     선선발       1
# 82816  ...        1      추추입        4     None       1     추추입       2
#
#       금회2일차전법  rank 금회3일차
# 0        None  None   NaN
# 1        None     3   NaN
# 2        None     2   NaN
# 3        None  None   NaN
# 4        None  None   NaN
# ...       ...   ...   ...
# 82812     마마크  None   NaN
# 82813     추추입  None   NaN
# 82814    젖젖히기  None   NaN
# 82815     추추입     1   NaN
# 82816     마마크  None   NaN
#
# [82817 rows x 59 columns]

# %%
final_data_merged.drop('금회3일차', axis=1).to_csv('KCycle_data.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# # result_df를 수집할때, 제외된 경기도 제외하도록 해야됨

# %%
연도, 회차, 일차 = 2017, 8, 1
method = 3
threshold = 3

print(f'연도: {연도}, 회차: {회차}, 일차: {일차}')

url = f'https://www.kcycle.or.kr/contents/information/fixedChuljuPage.do?stndYear={연도}&tms_dayOrd={회차}-{일차}'
driver.get(url)

html = driver.page_source
soup_race = BeautifulSoup(html, 'html.parser')

strong_text = soup_race.find('strong').text

# 날짜 패턴 검색 (연도 포함)
date_match = re.search(r'(\d{4})년 (\d{2})월 (\d{2})일', strong_text)
if date_match:
    # 'YYMMDD' 형식
    year_last_two = date_match.group(1)[-2:]
    month = date_match.group(2)  
    day = date_match.group(3)  
    Date = year_last_two + month + day
else:
    Date = None

base_raw = soup_race.find('div', class_='turn badge-group mt15')
race_string = [td.get_text(strip=True) for td in base_raw.find_all('span')]

numbers = [re.search(r'\d+', item).group() for item in race_string if '광' in item]

day_data_merged = pd.DataFrame()
processed_races = []

for i in range(len(numbers)):
    try:
        target_경기 = numbers[i]
        div_found = KC.find_race(soup_race, race_num=target_경기)
        
        date_info = pd.DataFrame({
            "BASE_YEAR": [연도] * 7,
            "TME_VALUE": [회차] * 7,
            "DAY_ORD_VALUE": [일차] * 7,
            "RACE_NO": [target_경기] * 7,
            "Date": [Date] * 7
        })
        
        data_base = KC.baseinfo(div_found, method=method, threshold=3)
        # print(len(data_base))
        
        data_training = KC.training_info(div_found)
        
        data_recent_tmp = KC.recent_result(div_found)
        data_recent = KC.recent_result_process(data_recent_tmp)
    
        data_merged = pd.concat([
            date_info,
            data_base,
            data_training[['훈련일수', '훈련내용']],
            data_recent.iloc[:, 2:],
        ], axis=1)
    
        day_data_merged = pd.concat([day_data_merged, data_merged], ignore_index=True)
        day_data_merged.reset_index(drop=True, inplace=True)
        processed_races.append(target_경기)
    except Exception as e:
        print(f"Error processing race {target_경기} in 회차 {회차} and 일차 {일차}: {e}")
        continue

url = f'https://www.kcycle.or.kr/contents/information/raceResultPage.do?stndYear={연도}&tms_dayOrd={회차}-{일차}'
response = requests.get(url)
html_content = response.text
soup_result = BeautifulSoup(html_content, 'html.parser')
# print(processed_races)
result_df = KC.fetch_race_results(soup_race, soup_result, 연도, 회차, 일차)
filtered_results = result_df[result_df['RACE_NO'].isin(processed_races)]
filtered_results.reset_index(drop=True, inplace=True)

print(filtered_results.shape, day_data_merged.shape)
day_data_merged = pd.concat([day_data_merged, filtered_results['rank']], axis=1)
print(day_data_merged.shape)
# Out:
# 연도: 2017, 회차: 8, 일차: 1
# Error processing race 04 in 회차 8 and 일차 1: Columns must be same length as key
# (91, 6) (91, 57)
# (91, 58)

# %%
year, meeting, day = 2017, 1, 1


circle_map = {
    '①': 1, '②': 2, '③': 3, '④': 4,
    '⑤': 5, '⑥': 6, '⑦': 7, '-': None
}

url = f'https://www.kcycle.or.kr/contents/information/raceResultPage.do?stndYear={year}&tms_dayOrd={meeting}-{day}'
response = requests.get(url)
html_content = response.text
soup = BeautifulSoup(html_content, 'html.parser')

table = soup.find('div', class_='table pcType')
tbody = table.find('tbody')
# print('1.51.51.5', tbody)
gwang_races = []
for tr in tbody.find_all('tr'):
    if tr.find('td', class_='gwang'):
        gwang_races.append(tr)
print('222:', gwang_races)
all_result = pd.DataFrame()

for race in gwang_races:
    print('333:', race)
    race_data = [td.get_text(strip=True) for td in race.find_all('td')]
    numbers = [circle_map[data[0]] for data in race_data[1:4] if data[0] in circle_map]

    # df = pd.DataFrame({
    #     "BASE_YEAR": [year] * 7,
    #     "TME_VALUE": [meeting] * 7,
    #     "DAY_ORD_VALUE": [day] * 7,
    #     "RACE_NO": [race] * 7,
    #     'line': range(1, 8),  # Assuming a maximum of 8 lines per race
    #     'rank': [None] * 7  # Create 8 rows initialized with None
    # })
    print('444:', race_data)
    df = pd.DataFrame({
        'line': range(1, 8),  # Assuming a maximum of 8 lines per race
        'rank': [None] * 7,  # Create 7 rows initialized with None
        'BASE_YEAR': [year] * 7,
        'TME_VALUE': [meeting] * 7,
        'DAY_ORD_VALUE': [day] * 7,
        'RACE_NO': [race_data[0].split()[-1]] * 7  # Assuming the race number is included in the first td
    })
    
    for idx, num in enumerate(numbers):
        if num is not None:
            df.at[num-1, 'rank'] = idx + 1

    all_result = pd.concat([all_result, df], ignore_index=True)
# Out:
# 1.51.51.5 <tbody>
# <tr>
# <td class="chang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=1">창원01</a>
# <br/>
# </td>
# <td>①주석진</td>
# <td>⑦양진우</td>
# <td>⑤고재준</td>
# <td>
#
#
#
# 											(1)1.3
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(7)16.8<br/>
# </td>
# <td>
#
#
#
# 											(1-7)20.8
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)19.6
#
#
# 								</td>
# <td>
#
#
#
# 											(1-5-7)28.2
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=1"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="chang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=2">창원02</a>
# <br>
# </br></td>
# <td>⑦류성희</td>
# <td>⑤전형진</td>
# <td>①김경태</td>
# <td>
#
#
#
# 											(7)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(7)1.0<br/>(5)1.9<br/>
# </td>
# <td>
#
#
#
# 											(7-5)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(5-7)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-5-7)7.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=2"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="chang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=3">창원03</a>
# <br>
# </br></td>
# <td>③노태경</td>
# <td>⑥이효석</td>
# <td>⑤임규태</td>
# <td>
#
#
#
# 											(3)1.1
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(6)2.7<br/>
# </td>
# <td>
#
#
#
# 											(3-6)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											(3-6)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)13.8
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=002&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=3"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4">광명01</a>
# <br>
# </br></td>
# <td>⑦구광규</td>
# <td>③한지혁</td>
# <td>②설영석</td>
# <td>
#
#
#
# 											(7)5.3
#
#
# 								</td>
# <td>
#
#
#
# 											(7)2.1<br/>(3)2.9<br/>
# </td>
# <td>
#
#
#
# 											(7-3)187.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)145.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)346.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5">광명02</a>
# <br>
# </br></td>
# <td>③문현진</td>
# <td>⑥김형우</td>
# <td>④이기주</td>
# <td>
#
#
#
# 											(3)1.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(6)7.3<br/>
# </td>
# <td>
#
#
#
# 											(3-6)13.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3-6)11.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4-6)6.5
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6">광명03</a>
# <br>
# </br></td>
# <td>④김민준</td>
# <td>②김환진</td>
# <td>⑦최종태</td>
# <td>
#
#
#
# 											(4)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(4)1.2<br/>(2)1.5<br/>
# </td>
# <td>
#
#
#
# 											(4-2)5.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4)2.8
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4-7)3.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7">광명04</a>
# <br>
# </br></td>
# <td>③이진영</td>
# <td>④윤현구</td>
# <td>②강동국</td>
# <td>
#
#
#
# 											(3)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(4)1.1<br/>
# </td>
# <td>
#
#
#
# 											(3-4)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-4)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8">광명05</a>
# <br>
# </br></td>
# <td>③강성배</td>
# <td>⑦황종대</td>
# <td>①주병환</td>
# <td>
#
#
#
# 											(3)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.1<br/>(7)2.3<br/>
# </td>
# <td>
#
#
#
# 											(3-7)2.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9">광명06</a>
# <br>
# </br></td>
# <td>⑤김정태</td>
# <td>②임영완</td>
# <td>③공민규</td>
# <td>
#
#
#
# 											(5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(2)2.9<br/>
# </td>
# <td>
#
#
#
# 											(5-2)3.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-5)3.1
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10">광명07</a>
# <br>
# </br></td>
# <td>②정재원</td>
# <td>⑤박덕인</td>
# <td>⑦박동수</td>
# <td>
#
#
#
# 											(2)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2)1.0<br/>(5)1.2<br/>
# </td>
# <td>
#
#
#
# 											(2-5)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5-7)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11">광명08</a>
# <br>
# </br></td>
# <td>⑤고병수</td>
# <td>⑥김일규</td>
# <td>③박대한</td>
# <td>
#
#
#
# 											(5)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.2<br/>(6)2.1<br/>
# </td>
# <td>
#
#
#
# 											(5-6)6.8
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)4.8
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12">광명09</a>
# <br>
# </br></td>
# <td>⑦박성호</td>
# <td>①최지윤</td>
# <td>③황정연</td>
# <td>
#
#
#
# 											(7)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(7)1.0<br/>(1)1.3<br/>
# </td>
# <td>
#
#
#
# 											(7-1)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13">광명10</a>
# <br>
# </br></td>
# <td>⑤김희준</td>
# <td>⑥박상서</td>
# <td>③임세윤</td>
# <td>
#
#
#
# 											(5)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(5-6)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)16.6
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14">광명11</a>
# <br>
# </br></td>
# <td>①유경원</td>
# <td>⑥강준영</td>
# <td>⑦정해권</td>
# <td>
#
#
#
# 											(1)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.6
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6-7)5.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15">광명12</a>
# <br>
# </br></td>
# <td>①이으뜸</td>
# <td>⑦신은섭</td>
# <td>③이욱동</td>
# <td>
#
#
#
# 											(1)3.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.1<br/>(7)1.2<br/>
# </td>
# <td>
#
#
#
# 											(1-7)4.3
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16">광명13</a>
# <br>
# </br></td>
# <td>③김주상</td>
# <td>②류재민</td>
# <td>⑦공민우</td>
# <td>
#
#
#
# 											(3)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(2)2.5<br/>
# </td>
# <td>
#
#
#
# 											(3-2)2.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)7.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17">광명14</a>
# <br>
# </br></td>
# <td>①성낙송</td>
# <td>⑥박지영</td>
# <td>④원신재</td>
# <td>
#
#
#
# 											(1)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)1.8<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-4-6)18.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# </tbody>
# 222: [<tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4">광명01</a>
# <br>
# </br></td>
# <td>⑦구광규</td>
# <td>③한지혁</td>
# <td>②설영석</td>
# <td>
#
#
#
# 											(7)5.3
#
#
# 								</td>
# <td>
#
#
#
# 											(7)2.1<br/>(3)2.9<br/>
# </td>
# <td>
#
#
#
# 											(7-3)187.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)145.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)346.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5">광명02</a>
# <br>
# </br></td>
# <td>③문현진</td>
# <td>⑥김형우</td>
# <td>④이기주</td>
# <td>
#
#
#
# 											(3)1.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(6)7.3<br/>
# </td>
# <td>
#
#
#
# 											(3-6)13.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3-6)11.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4-6)6.5
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6">광명03</a>
# <br>
# </br></td>
# <td>④김민준</td>
# <td>②김환진</td>
# <td>⑦최종태</td>
# <td>
#
#
#
# 											(4)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(4)1.2<br/>(2)1.5<br/>
# </td>
# <td>
#
#
#
# 											(4-2)5.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4)2.8
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4-7)3.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7">광명04</a>
# <br>
# </br></td>
# <td>③이진영</td>
# <td>④윤현구</td>
# <td>②강동국</td>
# <td>
#
#
#
# 											(3)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(4)1.1<br/>
# </td>
# <td>
#
#
#
# 											(3-4)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-4)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8">광명05</a>
# <br>
# </br></td>
# <td>③강성배</td>
# <td>⑦황종대</td>
# <td>①주병환</td>
# <td>
#
#
#
# 											(3)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.1<br/>(7)2.3<br/>
# </td>
# <td>
#
#
#
# 											(3-7)2.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9">광명06</a>
# <br>
# </br></td>
# <td>⑤김정태</td>
# <td>②임영완</td>
# <td>③공민규</td>
# <td>
#
#
#
# 											(5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(2)2.9<br/>
# </td>
# <td>
#
#
#
# 											(5-2)3.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-5)3.1
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10">광명07</a>
# <br>
# </br></td>
# <td>②정재원</td>
# <td>⑤박덕인</td>
# <td>⑦박동수</td>
# <td>
#
#
#
# 											(2)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2)1.0<br/>(5)1.2<br/>
# </td>
# <td>
#
#
#
# 											(2-5)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5-7)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11">광명08</a>
# <br>
# </br></td>
# <td>⑤고병수</td>
# <td>⑥김일규</td>
# <td>③박대한</td>
# <td>
#
#
#
# 											(5)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.2<br/>(6)2.1<br/>
# </td>
# <td>
#
#
#
# 											(5-6)6.8
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)4.8
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12">광명09</a>
# <br>
# </br></td>
# <td>⑦박성호</td>
# <td>①최지윤</td>
# <td>③황정연</td>
# <td>
#
#
#
# 											(7)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(7)1.0<br/>(1)1.3<br/>
# </td>
# <td>
#
#
#
# 											(7-1)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13">광명10</a>
# <br>
# </br></td>
# <td>⑤김희준</td>
# <td>⑥박상서</td>
# <td>③임세윤</td>
# <td>
#
#
#
# 											(5)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(5-6)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)16.6
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14">광명11</a>
# <br>
# </br></td>
# <td>①유경원</td>
# <td>⑥강준영</td>
# <td>⑦정해권</td>
# <td>
#
#
#
# 											(1)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.6
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6-7)5.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15">광명12</a>
# <br>
# </br></td>
# <td>①이으뜸</td>
# <td>⑦신은섭</td>
# <td>③이욱동</td>
# <td>
#
#
#
# 											(1)3.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.1<br/>(7)1.2<br/>
# </td>
# <td>
#
#
#
# 											(1-7)4.3
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16">광명13</a>
# <br>
# </br></td>
# <td>③김주상</td>
# <td>②류재민</td>
# <td>⑦공민우</td>
# <td>
#
#
#
# 											(3)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(2)2.5<br/>
# </td>
# <td>
#
#
#
# 											(3-2)2.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)7.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>, <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17">광명14</a>
# <br>
# </br></td>
# <td>①성낙송</td>
# <td>⑥박지영</td>
# <td>④원신재</td>
# <td>
#
#
#
# 											(1)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)1.8<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-4-6)18.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>]
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4">광명01</a>
# <br>
# </br></td>
# <td>⑦구광규</td>
# <td>③한지혁</td>
# <td>②설영석</td>
# <td>
#
#
#
# 											(7)5.3
#
#
# 								</td>
# <td>
#
#
#
# 											(7)2.1<br/>(3)2.9<br/>
# </td>
# <td>
#
#
#
# 											(7-3)187.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)145.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)346.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=01&amp;allYN=N&amp;chkRaceNo=4"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명01', '⑦구광규', '③한지혁', '②설영석', '(7)5.3', '(7)2.1(3)2.9', '(7-3)187.6', '(3-7)145.3', '(2-3-7)346.0', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5">광명02</a>
# <br>
# </br></td>
# <td>③문현진</td>
# <td>⑥김형우</td>
# <td>④이기주</td>
# <td>
#
#
#
# 											(3)1.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(6)7.3<br/>
# </td>
# <td>
#
#
#
# 											(3-6)13.3
#
#
# 								</td>
# <td>
#
#
#
# 											(3-6)11.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4-6)6.5
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=02&amp;allYN=N&amp;chkRaceNo=5"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명02', '③문현진', '⑥김형우', '④이기주', '(3)1.3', '(3)1.0(6)7.3', '(3-6)13.3', '(3-6)11.9', '(3-4-6)6.5', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6">광명03</a>
# <br>
# </br></td>
# <td>④김민준</td>
# <td>②김환진</td>
# <td>⑦최종태</td>
# <td>
#
#
#
# 											(4)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(4)1.2<br/>(2)1.5<br/>
# </td>
# <td>
#
#
#
# 											(4-2)5.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4)2.8
#
#
# 								</td>
# <td>
#
#
#
# 											(2-4-7)3.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=03&amp;allYN=N&amp;chkRaceNo=6"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명03', '④김민준', '②김환진', '⑦최종태', '(4)1.7', '(4)1.2(2)1.5', '(4-2)5.6', '(2-4)2.8', '(2-4-7)3.9', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7">광명04</a>
# <br>
# </br></td>
# <td>③이진영</td>
# <td>④윤현구</td>
# <td>②강동국</td>
# <td>
#
#
#
# 											(3)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(4)1.1<br/>
# </td>
# <td>
#
#
#
# 											(3-4)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-4)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-4)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=04&amp;allYN=N&amp;chkRaceNo=7"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명04', '③이진영', '④윤현구', '②강동국', '(3)1.5', '(3)1.0(4)1.1', '(3-4)2.4', '(3-4)1.5', '(2-3-4)3.4', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8">광명05</a>
# <br>
# </br></td>
# <td>③강성배</td>
# <td>⑦황종대</td>
# <td>①주병환</td>
# <td>
#
#
#
# 											(3)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.1<br/>(7)2.3<br/>
# </td>
# <td>
#
#
#
# 											(3-7)2.9
#
#
# 								</td>
# <td>
#
#
#
# 											(3-7)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=05&amp;allYN=N&amp;chkRaceNo=8"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명05', '③강성배', '⑦황종대', '①주병환', '(3)1.6', '(3)1.1(7)2.3', '(3-7)2.9', '(3-7)2.1', '(1-3-7)1.8', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9">광명06</a>
# <br>
# </br></td>
# <td>⑤김정태</td>
# <td>②임영완</td>
# <td>③공민규</td>
# <td>
#
#
#
# 											(5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(2)2.9<br/>
# </td>
# <td>
#
#
#
# 											(5-2)3.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)3.4
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-5)3.1
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=06&amp;allYN=N&amp;chkRaceNo=9"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명06', '⑤김정태', '②임영완', '③공민규', '(5)1.2', '(5)1.0(2)2.9', '(5-2)3.6', '(2-5)3.4', '(2-3-5)3.1', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10">광명07</a>
# <br>
# </br></td>
# <td>②정재원</td>
# <td>⑤박덕인</td>
# <td>⑦박동수</td>
# <td>
#
#
#
# 											(2)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2)1.0<br/>(5)1.2<br/>
# </td>
# <td>
#
#
#
# 											(2-5)1.6
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-5-7)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=07&amp;allYN=N&amp;chkRaceNo=10"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명07', '②정재원', '⑤박덕인', '⑦박동수', '(2)1.6', '(2)1.0(5)1.2', '(2-5)1.6', '(2-5)1.2', '(2-5-7)1.9', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11">광명08</a>
# <br>
# </br></td>
# <td>⑤고병수</td>
# <td>⑥김일규</td>
# <td>③박대한</td>
# <td>
#
#
#
# 											(5)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.2<br/>(6)2.1<br/>
# </td>
# <td>
#
#
#
# 											(5-6)6.8
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)4.8
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)1.7
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=08&amp;allYN=N&amp;chkRaceNo=11"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명08', '⑤고병수', '⑥김일규', '③박대한', '(5)1.7', '(5)1.2(6)2.1', '(5-6)6.8', '(5-6)4.8', '(3-5-6)1.7', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12">광명09</a>
# <br>
# </br></td>
# <td>⑦박성호</td>
# <td>①최지윤</td>
# <td>③황정연</td>
# <td>
#
#
#
# 											(7)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(7)1.0<br/>(1)1.3<br/>
# </td>
# <td>
#
#
#
# 											(7-1)2.1
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.8
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)2.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=09&amp;allYN=N&amp;chkRaceNo=12"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명09', '⑦박성호', '①최지윤', '③황정연', '(7)1.0', '(7)1.0(1)1.3', '(7-1)2.1', '(1-7)1.8', '(1-3-7)2.4', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13">광명10</a>
# <br>
# </br></td>
# <td>⑤김희준</td>
# <td>⑥박상서</td>
# <td>③임세윤</td>
# <td>
#
#
#
# 											(5)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(5)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(5-6)1.9
#
#
# 								</td>
# <td>
#
#
#
# 											(5-6)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											(3-5-6)16.6
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=10&amp;allYN=N&amp;chkRaceNo=13"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명10', '⑤김희준', '⑥박상서', '③임세윤', '(5)1.4', '(5)1.0(6)2.0', '(5-6)1.9', '(5-6)1.4', '(3-5-6)16.6', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14">광명11</a>
# <br>
# </br></td>
# <td>①유경원</td>
# <td>⑥강준영</td>
# <td>⑦정해권</td>
# <td>
#
#
#
# 											(1)1.5
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)2.0<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.6
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6-7)5.0
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=11&amp;allYN=N&amp;chkRaceNo=14"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명11', '①유경원', '⑥강준영', '⑦정해권', '(1)1.5', '(1)1.0(6)2.0', '(1-6)2.6', '(1-6)2.0', '(1-6-7)5.0', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15">광명12</a>
# <br>
# </br></td>
# <td>①이으뜸</td>
# <td>⑦신은섭</td>
# <td>③이욱동</td>
# <td>
#
#
#
# 											(1)3.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.1<br/>(7)1.2<br/>
# </td>
# <td>
#
#
#
# 											(1-7)4.3
#
#
# 								</td>
# <td>
#
#
#
# 											(1-7)1.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-3-7)1.4
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=12&amp;allYN=N&amp;chkRaceNo=15"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명12', '①이으뜸', '⑦신은섭', '③이욱동', '(1)3.2', '(1)1.1(7)1.2', '(1-7)4.3', '(1-7)1.2', '(1-3-7)1.4', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16">광명13</a>
# <br>
# </br></td>
# <td>③김주상</td>
# <td>②류재민</td>
# <td>⑦공민우</td>
# <td>
#
#
#
# 											(3)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(3)1.0<br/>(2)2.5<br/>
# </td>
# <td>
#
#
#
# 											(3-2)2.3
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(2-3-7)7.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=13&amp;allYN=N&amp;chkRaceNo=16"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명13', '③김주상', '②류재민', '⑦공민우', '(3)1.0', '(3)1.0(2)2.5', '(3-2)2.3', '(2-3)2.2', '(2-3-7)7.3', '-', '-', '완료', '']
# 333: <tr>
# <td class="gwang">
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17">광명14</a>
# <br>
# </br></td>
# <td>①성낙송</td>
# <td>⑥박지영</td>
# <td>④원신재</td>
# <td>
#
#
#
# 											(1)1.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1)1.0<br/>(6)1.8<br/>
# </td>
# <td>
#
#
#
# 											(1-6)2.0
#
#
# 								</td>
# <td>
#
#
#
# 											(1-6)2.2
#
#
# 								</td>
# <td>
#
#
#
# 											(1-4-6)18.3
#
#
# 								</td>
# <td>
#
#
#
# 											-
#
#
# 							    </td>
# <td>-</td>
# <td>
# <a href="/contents/information/raceResultDetailPage.do?stndYear=2017&amp;raceDt=0106&amp;tms_dayOrd=1-1&amp;tms=1&amp;tmsNoNum=1&amp;dayOrd=1&amp;meetCd=001&amp;raceNo=14&amp;allYN=N&amp;chkRaceNo=17"><span class="badge-sm w-a red">완료</span> </a>
# </td>
# <td>
# </td>
# </tr>
# 444: ['광명14', '①성낙송', '⑥박지영', '④원신재', '(1)1.0', '(1)1.0(6)1.8', '(1-6)2.0', '(1-6)2.2', '(1-4-6)18.3', '-', '-', '완료', '']

# %%
all_result
# Out:
#     line  rank  BASE_YEAR  TME_VALUE  DAY_ORD_VALUE RACE_NO
# 0      1  None       2017          1              1    광명01
# 1      2     3       2017          1              1    광명01
# 2      3     2       2017          1              1    광명01
# 3      4  None       2017          1              1    광명01
# 4      5  None       2017          1              1    광명01
# ..   ...   ...        ...        ...            ...     ...
# 93     3  None       2017          1              1    광명14
# 94     4     3       2017          1              1    광명14
# 95     5  None       2017          1              1    광명14
# 96     6     2       2017          1              1    광명14
# 97     7  None       2017          1              1    광명14
#
# [98 rows x 6 columns]
